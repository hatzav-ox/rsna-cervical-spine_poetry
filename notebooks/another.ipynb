# %%
import numpy as np
import os
import pandas as pd
import pydicom
from pydicom.dataset import FileDataset
from pathlib import Path
from typing import Generator
from sklearn.model_selection import KFold, StratifiedKFold

import nibabel as nib
import numpy as np
from nibabel import Nifti1Image
import matplotlib.pyplot as plt
from matplotlib import animation

from IPython.display import HTML

# %%
image_sizes = [128, 128, 128]

data_dir = "/Volumes/Data/kaggle/raw"

# %%
df_train: pd.DataFrame = pd.read_csv(os.path.join(data_dir, 'train.csv'))

df_bounding: pd.DataFrame = pd.read_csv(
  os.path.join(data_dir, 'train_bounding_boxes.csv')
)

mask_files: list = os.listdir(f'{data_dir}/segmentations')
df_mask: pd.DataFrame = pd.DataFrame({
    'mask_file': mask_files,
})
df_mask['StudyInstanceUID'] = df_mask['mask_file'].apply(
  lambda x: x[:-4]
)
df_mask['mask_file'] = df_mask['mask_file'].apply(
  lambda x: os.path.join(data_dir, 'segmentations', x)
)
df = df_train.merge(df_mask, on='StudyInstanceUID', how='left')
df['image_folder'] = df['StudyInstanceUID'].apply(
  lambda x: os.path.join(data_dir, 'train_images', x)
)
df_seg = df[df["mask_file"].notna()].reset_index(drop=True)

kf: KFold = KFold(5)
df_seg['fold'] = -1
for fold, (train_idx, validation_idx) in enumerate(kf.split(df_seg, df_seg)):
  df_seg.loc[validation_idx, 'fold'] = fold

# %%
niiSlices = nib.load(
  filename=df_seg.loc[0, "mask_file"]
).get_fdata()[:, ::-1, ::-1].transpose(2, 1, 0)

# %%
fig, ax = plt.subplots(figsize=(6,6))

# ims is a list of lists, each row is a list of artists to draw in the
ims = []
for i, frame in enumerate(niiSlices):
    im = ax.imshow( frame )
    ttl = plt.text(
        0.5, 
        1.01,  
        np.unique(frame), 
        horizontalalignment='center', 
        verticalalignment='bottom', 
        transform=ax.transAxes
    )

    ims.append([im, ttl])

ani = animation.ArtistAnimation(fig, ims, interval=10 ,repeat_delay=1000)

plt.close()
HTML(ani.to_html5_video())
# Out:
# /Users/inventrohyder/Downloads/rsna-cervical-spine/.venv/lib/python3.10/site-packages/matplotlib/animation.py:879: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# <video width="600" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
def load_dicoms(path: str) -> list[FileDataset]:
  dicom_file_names: list[str] = os.listdir(path=path)
  
  dicom_files: list[FileDataset] = []
  
  for dicom_file_name in dicom_file_names:
    dicom_files.append(
      pydicom.read_file(os.path.join(path, dicom_file_name))
    )
  
  
  return sorted(
    dicom_files,
    key= lambda x: x.InstanceNumber
  )

# %%
study: str = "1.2.826.0.1.3680043.5783"
study_row: pd.DataFrame = df[df["StudyInstanceUID"] == study].reset_index(drop=True)
data = load_dicoms(path = study_row.loc[0, "image_folder"])
data
# Out:
# [Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.1
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.1
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183317.657543'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '1'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -15.045]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.2
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.2
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183328.524549'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '2'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -15.358]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.3
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.3
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183339.509016'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '3'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -15.670]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.4
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.4
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183350.468818'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '4'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -15.983]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.5
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.5
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183401.513045'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '5'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -16.295]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.6
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.6
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183412.421821'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '6'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -16.608]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.7
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.7
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183413.720790'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '7'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -16.920]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.8
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.8
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183414.849324'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '8'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -17.233]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.9
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.9
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183416.081800'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '9'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -17.545]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.10
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.10
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183317.757735'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '10'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -17.858]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.11
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.11
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183318.873365'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '11'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -18.170]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.12
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.12
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183319.917997'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '12'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -18.483]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.13
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.13
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183320.949993'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '13'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -18.795]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.14
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.14
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183321.984666'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '14'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -19.108]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.15
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.15
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183323.022370'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '15'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -19.420]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.16
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.16
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183324.099450'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '16'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -19.733]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.17
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.17
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183325.232160'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '17'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -20.045]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.18
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.18
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183326.321986'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '18'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -20.358]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.19
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.19
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183327.420793'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '19'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -20.670]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.20
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.20
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183328.626922'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '20'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -20.983]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.21
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.21
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183329.735797'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '21'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -21.295]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.22
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.22
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183330.769839'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
# ...
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.595
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.595
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183411.949846'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '595'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -200.671]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.596
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.596
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183412.045293'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '596'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -200.983]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.597
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.597
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183412.140362'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '597'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -201.296]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.598
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.598
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183412.234817'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '598'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -201.608]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.599
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.599
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183412.329423'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '599'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -201.921]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.600
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.600
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183412.615106'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '600'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -202.233]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements,
#  Dataset.file_meta -------------------------------
#  (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
#  (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
#  (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.5783.1.601
#  (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
#  (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
#  (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.3.0'
#  -------------------------------------------------
#  (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.5783.1.601
#  (0008, 0023) Content Date                        DA: '20220727'
#  (0008, 0033) Content Time                        TM: '183412.711006'
#  (0010, 0010) Patient's Name                      PN: '5783'
#  (0010, 0020) Patient ID                          LO: '5783'
#  (0018, 0050) Slice Thickness                     DS: '0.625'
#  (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.5783
#  (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.5783.1
#  (0020, 0013) Instance Number                     IS: '601'
#  (0020, 0032) Image Position (Patient)            DS: [-102.500, -72.167, -202.546]
#  (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
#  (0028, 0002) Samples per Pixel                   US: 1
#  (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#  (0028, 0010) Rows                                US: 512
#  (0028, 0011) Columns                             US: 512
#  (0028, 0030) Pixel Spacing                       DS: [0.400391, 0.400391]
#  (0028, 0100) Bits Allocated                      US: 16
#  (0028, 0101) Bits Stored                         US: 16
#  (0028, 0102) High Bit                            US: 15
#  (0028, 0103) Pixel Representation                US: 1
#  (0028, 1050) Window Center                       DS: '300.0'
#  (0028, 1051) Window Width                        DS: '2000.0'
#  (0028, 1052) Rescale Intercept                   DS: '-1024.0'
#  (0028, 1053) Rescale Slope                       DS: '1.0'
#  (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements]

# %%
fig, ax = plt.subplots(figsize=(6,6))

# ims is a list of lists, each row is a list of artists to draw in the
ims = []
for i, frame in enumerate(data):
    im = ax.imshow( frame.pixel_array, cmap=plt.cm.bone )
    slice_number: int = i + 1
    df_current_study = df_bounding[df_bounding["StudyInstanceUID"] == study]
    df_current_study_slice = df_current_study[
      df_current_study["slice_number"] == slice_number
    ]
    
    if len(df_current_study_slice) > 0:
      x_min: float = df_current_study_slice.reset_index().loc[0, "x"]
      y_min: float = df_current_study_slice.reset_index().loc[0, "y"]
      w: float = df_current_study_slice.reset_index().loc[0, "width"]
      h: float = df_current_study_slice.reset_index().loc[0, "height"]
      ttl, = ax.plot(
        [x_min, x_min+w, x_min+w, x_min, x_min],
        [y_min, y_min, y_min+h, y_min+h, y_min],
        color="red",
        linewidth=1
      )
      ims.append([im, ttl])
    else:
      ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=10 ,repeat_delay=1000)

plt.close()
HTML(ani.to_html5_video())
# Out:
# <video width="600" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
ani = animation.ArtistAnimation(fig, ims, interval=10 ,repeat_delay=2000)

HTML(ani.to_html5_video())
# Out:
# <video width="600" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
df_bounding.groupby("StudyInstanceUID").count().sort_values(by="x")
# Out:
#                              x    y  width  height  slice_number
# StudyInstanceUID
# 1.2.826.0.1.3680043.780      2    2      2       2             2
# 1.2.826.0.1.3680043.27016    2    2      2       2             2
# 1.2.826.0.1.3680043.10579    3    3      3       3             3
# 1.2.826.0.1.3680043.17208    4    4      4       4             4
# 1.2.826.0.1.3680043.12785    5    5      5       5             5
# ...                        ...  ...    ...     ...           ...
# 1.2.826.0.1.3680043.19778  100  100    100     100           100
# 1.2.826.0.1.3680043.21321  132  132    132     132           132
# 1.2.826.0.1.3680043.31077  143  143    143     143           143
# 1.2.826.0.1.3680043.25772  166  166    166     166           166
# 1.2.826.0.1.3680043.5783   167  167    167     167           167
#
# [235 rows x 5 columns]
